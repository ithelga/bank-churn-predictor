# %% [markdown]
# <a href="https://colab.research.google.com/github/ithelga/bank-churn-predictor/blob/main/notebooks/Team2_HW4_Ensemble_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ансамбли моделей

# %%
import numpy as np
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from matplotlib.colors import LinearSegmentedColormap
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, precision_score, recall_score, make_scorer
from sklearn.ensemble import RandomForestClassifier
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, RandomizedSearchCV

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
colors = ["#FFAFCC", "#FFC8DD", "#CDB4DB", "#BDE0FE", "#A2D2FF"]
graph_path = 'drive/MyDrive/Colab Notebooks/Bank churn predictor/graph'

# %%
data_path = 'drive/MyDrive/Colab Notebooks/Bank churn predictor/data'

row_df = pd.read_csv(f'{data_path}/row_dataset.csv')                   # исходные данные
preprocessed_df = pd.read_csv(f'{data_path}/preprocessed_dataset.csv') # предобработанные данные
derived_df = pd.read_csv(f'{data_path}/derived_dataset.csv')           # сгенерированные признаки
extract_df = pd.read_csv(f'{data_path}/extract_dataset.csv')           # отобранные признаки
cleaned_df = pd.read_csv(f'{data_path}/cleaned_dataset.csv')           # очищенные от выбросов

# %% [markdown]
# # Выбор модели

# %%
pip install lightgbm xgboost
# Out:
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from lightgbm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lightgbm) (1.15.3)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)

# %%
def evaluate_models_ensemble(df, dataset_name, is_raw_data=False):
    """
    Обучение и оценка ансамблей (RandomForest, LightGBM, XGBoost)

    Параметры:
    - df: DataFrame с данными
    - dataset_name: название датасета
    - is_raw_data: удаляет категориальные признаки (для raw_df)

    Возвращает:
    - Список словарей с метриками
    """
    data = df.copy()

    non_features = ['RowNumber', 'CustomerId', 'Surname']
    if 'Exited' in data.columns:
        target = data['Exited']
        features = data.drop(columns=['Exited'] + [col for col in non_features if col in data.columns])
    else:
        raise ValueError("Столбец 'Exited' не найден в данных.")

    if is_raw_data:
        cat_cols = features.select_dtypes(include=['object', 'category']).columns
        features = features.drop(columns=cat_cols)
        features = features.fillna(features.median())

    X_train, X_test, y_train, y_test = train_test_split(
        features, target,
        test_size=0.25,
        random_state=42,
        stratify=target
    )

    models = {
    'RandomForest': RandomForestClassifier(
        class_weight='balanced_subsample',
        n_estimators=200,
        min_samples_leaf=20,
        min_samples_split=10,
        max_features='sqrt',
        bootstrap=True,
        random_state=42,
        n_jobs=-1
    ),
    'LightGBM': LGBMClassifier(
        is_unbalance=True,
        n_estimators=200,
        random_state=42,
        n_jobs=-1,
        verbosity=-1,
        force_col_wise=True
    ),
    'XGBoost': XGBClassifier(
        scale_pos_weight=(y_train == 0).sum() / (y_train == 1).sum(),
        use_label_encoder=False,
        eval_metric='logloss',
        n_estimators=200,
        random_state=42,
        n_jobs=-1,
        verbosity=0
    )
    }

    results = []

    for model_name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        y_proba = model.predict_proba(X_test)[:, 1]

        metrics = {
            'Dataset': dataset_name,
            'Model': model_name,
            'F1': f1_score(y_test, y_pred),
            'ROC-AUC': roc_auc_score(y_test, y_proba),
            'Recall': recall_score(y_test, y_pred),
            'Precision': precision_score(y_test, y_pred)
        }

        results.append(metrics)

    return results

# %%
# Список датасетов и их характеристик
datasets = [
    {'data': row_df, 'name': 'Первоначальные данные', 'is_raw': True},
    {'data': preprocessed_df, 'name': 'Предобработанные данные', 'is_raw': False},
    {'data': derived_df, 'name': 'Сгенерированные признаки', 'is_raw': False},
    {'data': extract_df, 'name': 'Отобранные признаки', 'is_raw': False},
    {'data': cleaned_df, 'name': 'Отобранные признаки без выбросов', 'is_raw': False}
]

# %%
all_results_ensemble = []
for dataset in datasets:
    all_results_ensemble.extend(
        evaluate_models_ensemble(
            dataset['data'],
            dataset['name'],
            is_raw_data=dataset['is_raw']
        )
    )

results_ensemble_df = pd.DataFrame(all_results_ensemble)

# %%
# Настраиваем порядок датасетов
dataset_order = [
    'Первоначальные данные',
    'Предобработанные данные',
    'Сгенерированные признаки',
    'Отобранные признаки',
    'Отобранные признаки без выбросов'
]

# %%
def style_comparison_by_column(df):
    def _style(row):
        styles = []
        for i, val in enumerate(row):
            if pd.isna(val):
                styles.append('')
                continue

            col = df.columns[i]
            metric, model = col[0], col[1]
            base_color = model_colors[model]

            # Градиент внутри одного столбца (по значению)
            col_values = df[col].dropna()
            min_val, max_val = col_values.min(), col_values.max()
            norm = 0 if max_val == min_val else (val - min_val) / (max_val - min_val)

            # Интерполяция от 30% цвета → 100%
            min_intensity = 0.3
            intensity = min_intensity + norm * (1 - min_intensity)

            r, g, b = [int(base_color[i:i+2], 16) for i in (1, 3, 5)]
            r = int(255 - (255 - r) * intensity)
            g = int(255 - (255 - g) * intensity)
            b = int(255 - (255 - b) * intensity)

            style = f'background-color: rgb({r},{g},{b}); font-size: 12pt; text-align: center; padding: 5px;'

            # Жирный — если лучшее значение в строке по метрике
            same_metric = [c for c in df.columns if c[0] == metric]
            row_vals = [row[c] for c in same_metric if pd.notna(row[c])]
            row_max = max(row_vals)
            if val == row_max:
                style += 'font-weight: bold; color: black;'

            styles.append(style)
        return styles
    return _style

# %%
# Преобразуем результаты в pivot
pivot_ensemble_df = results_ensemble_df.set_index(['Dataset', 'Model']).unstack()
pivot_ensemble_df = pivot_ensemble_df.loc[dataset_order]

model_colors = {
    'RandomForest': "#CDB4DB",
    'LightGBM': "#FFAFCC",
    'XGBoost': "#A2D2FF"
}

table_styles = [
    {'selector': 'th',
     'props': [('background-color', 'white'),
               ('color', 'black'),
               ('text-align', 'center'),
               ('font-size', '12pt'),
               ('padding', '5px')]},
    {'selector': 'th.level0',
     'props': [('font-weight', 'bold'),
               ('border-bottom', '1px solid #aaa'),
               ('text-align', 'center')]},
    {'selector': 'th.level1',
     'props': [('font-style', 'italic')]},
    {'selector': 'td',
     'props': [('padding', '8px'),
               ('border', '1px solid #eee')]}
]

styled_ensemble_result = pivot_ensemble_df.style \
    .format("{:.3f}") \
    .apply(style_comparison_by_column(pivot_ensemble_df), axis=1) \
    .set_table_styles(table_styles) \
    .set_caption(
        f"<span style='font-size:16pt'>Сравнение ансамблей: "
        f"<span style='color:{model_colors['RandomForest']}; font-weight:bold'>RandomForest</span>, "
        f"<span style='color:{model_colors['LightGBM']}; font-weight:bold'>LightGBM</span>, "
        f"<span style='color:{model_colors['XGBoost']}; font-weight:bold'>XGBoost</span></span>"
    ) \
    .set_properties(**{'min-width': '120px'})
styled_ensemble_result
# Out:
# <style type="text/css">
# #T_06e60 th {
#   background-color: white;
#   color: black;
#   text-align: center;
#   font-size: 12pt;
#   padding: 5px;
# }
# #T_06e60 th.level0 {
#   font-weight: bold;
#   border-bottom: 1px solid #aaa;
#   text-align: center;
# }
# #T_06e60 th.level1 {
#   font-style: italic;
# }
# #T_06e60 td {
#   padding: 8px;
#   border: 1px solid #eee;
# }
# #T_06e60_row0_col0, #T_06e60_row0_col9 {
#   background-color: rgb(255,205,223);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row0_col1 {
#   background-color: rgb(219,201,229);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row0_col2, #T_06e60_row3_col5 {
#   background-color: rgb(187,222,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row0_col3, #T_06e60_row0_col6 {
#   background-color: rgb(255,214,229);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row0_col4 {
#   background-color: rgb(232,220,238);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row0_col5 {
#   background-color: rgb(200,228,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row0_col7, #T_06e60_row2_col4 {
#   background-color: rgb(225,210,233);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row0_col8 {
#   background-color: rgb(188,222,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row0_col10 {
#   background-color: rgb(220,203,230);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row0_col11 {
#   background-color: rgb(195,226,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row1_col0 {
#   background-color: rgb(255,175,204);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row1_col1, #T_06e60_row1_col10 {
#   background-color: rgb(205,180,219);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row1_col2, #T_06e60_row1_col5, #T_06e60_row3_col8 {
#   background-color: rgb(162,210,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row1_col3, #T_06e60_row1_col9, #T_06e60_row3_col6 {
#   background-color: rgb(255,175,204);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row1_col4, #T_06e60_row3_col7 {
#   background-color: rgb(205,180,219);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row1_col6 {
#   background-color: rgb(255,190,213);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row1_col7 {
#   background-color: rgb(232,221,239);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row1_col8 {
#   background-color: rgb(185,221,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row1_col11, #T_06e60_row2_col11 {
#   background-color: rgb(162,210,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row2_col0 {
#   background-color: rgb(255,188,212);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row2_col1 {
#   background-color: rgb(214,193,225);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row2_col2 {
#   background-color: rgb(167,212,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row2_col3 {
#   background-color: rgb(255,204,223);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row2_col5 {
#   background-color: rgb(184,220,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row2_col6 {
#   background-color: rgb(255,218,231);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row2_col7, #T_06e60_row4_col1, #T_06e60_row4_col4 {
#   background-color: rgb(240,232,244);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row2_col8 {
#   background-color: rgb(196,226,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row2_col9 {
#   background-color: rgb(255,183,209);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row2_col10 {
#   background-color: rgb(213,192,224);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row3_col0 {
#   background-color: rgb(255,189,213);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row3_col1 {
#   background-color: rgb(211,190,223);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row3_col2 {
#   background-color: rgb(174,216,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row3_col3 {
#   background-color: rgb(255,211,227);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row3_col4 {
#   background-color: rgb(219,202,229);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row3_col9 {
#   background-color: rgb(255,196,217);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row3_col10 {
#   background-color: rgb(217,198,227);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row3_col11 {
#   background-color: rgb(192,224,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row4_col0, #T_06e60_row4_col3, #T_06e60_row4_col6 {
#   background-color: rgb(255,231,239);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row4_col2, #T_06e60_row4_col5, #T_06e60_row4_col8, #T_06e60_row4_col11 {
#   background-color: rgb(227,241,255);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_06e60_row4_col7 {
#   background-color: rgb(227,213,235);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row4_col9 {
#   background-color: rgb(255,231,239);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_06e60_row4_col10 {
#   background-color: rgb(240,232,244);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# </style>
# <table id="T_06e60" class="dataframe">
#   <caption><span style='font-size:16pt'>Сравнение ансамблей: <span style='color:#CDB4DB; font-weight:bold'>RandomForest</span>, <span style='color:#FFAFCC; font-weight:bold'>LightGBM</span>, <span style='color:#A2D2FF; font-weight:bold'>XGBoost</span></span></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06e60_level0_col0" class="col_heading level0 col0" colspan="3">F1</th>
#       <th id="T_06e60_level0_col3" class="col_heading level0 col3" colspan="3">ROC-AUC</th>
#       <th id="T_06e60_level0_col6" class="col_heading level0 col6" colspan="3">Recall</th>
#       <th id="T_06e60_level0_col9" class="col_heading level0 col9" colspan="3">Precision</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Model</th>
#       <th id="T_06e60_level1_col0" class="col_heading level1 col0" >LightGBM</th>
#       <th id="T_06e60_level1_col1" class="co

# %% [markdown]
# # Обучение модели

# %% [markdown]
# Обучите модель из Спринта 2. Оцените метрики. Сделайте вывод.

# %%
def evaluate_models(df, dataset_name, is_raw_data=False):
    """
    Обучение и оценка моделей (логистическая регрессия и случайный лес с RandomizedSearchCV)

    Параметры:
    - df: DataFrame с данными
    - dataset_name: название датасета
    - is_raw_data: если True, удаляет категориальные признаки (только для row_df)

    Возвращает:
    - Список словарей с метриками для обеих моделей
    """
    data = df.copy()

    non_features = ['RowNumber', 'CustomerId', 'Surname']
    if 'Exited' in data.columns:
        target = data['Exited']
        features = data.drop(columns=['Exited'] + [col for col in non_features if col in data.columns])
    else:
        raise ValueError("Столбец 'Exited' не найден в данных.")

    if is_raw_data:
        cat_cols = features.select_dtypes(include=['object', 'category']).columns
        features = features.drop(columns=cat_cols)
        features = features.fillna(features.median())

    X_train, X_test, y_train, y_test = train_test_split(
        features, target,
        test_size=0.25,
        random_state=42,
        stratify=target
    )

    results = []

    # --- Logistic Regression ---
    lr_model = LogisticRegression(
        class_weight='balanced',
        max_iter=500,
        solver='lbfgs',
        random_state=42
    )
    lr_model.fit(X_train, y_train)
    y_pred_lr = lr_model.predict(X_test)
    y_proba_lr = lr_model.predict_proba(X_test)[:, 1]
    results.append({
        'Dataset': dataset_name,
        'Model': 'LogisticRegression',
        'F1': f1_score(y_test, y_pred_lr),
        'ROC-AUC': roc_auc_score(y_test, y_proba_lr),
        'Recall': recall_score(y_test, y_pred_lr),
        'Precision': precision_score(y_test, y_pred_lr)
    })

    # --- Random Forest + RandomizedSearchCV ---
    rf_base = RandomForestClassifier(
        class_weight='balanced',
        random_state=42,
        n_jobs=-1
    )

    param_dist = {
        'n_estimators': [100, 200],
        'max_depth': [5, 8, 10, None],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 5, 10],
        'max_features': ['sqrt', 'log2']
    }

    random_search = RandomizedSearchCV(
        rf_base,
        param_distributions=param_dist,
        n_iter=20,
        scoring=make_scorer(f1_score),
        cv=StratifiedKFold(n_splits=3, shuffle=True, random_state=42),
        n_jobs=-1,
        verbose=1,
        random_state=42
    )

    random_search.fit(X_train, y_train)
    best_rf = random_search.best_estimator_

    y_pred_rf = best_rf.predict(X_test)
    y_proba_rf = best_rf.predict_proba(X_test)[:, 1]

    results.append({
        'Dataset': dataset_name,
        'Model': 'RandomForest',
        'F1': f1_score(y_test, y_pred_rf),
        'ROC-AUC': roc_auc_score(y_test, y_proba_rf),
        'Recall': recall_score(y_test, y_pred_rf),
        'Precision': precision_score(y_test, y_pred_rf)
    })

    print(f"[{dataset_name}] Лучшие параметры RandomForest:", random_search.best_params_)

    return results

# %%
# Сбор результатов
all_results = []
for dataset in datasets:
    all_results.extend(evaluate_models(
        dataset['data'],
        dataset['name'],
        is_raw_data=dataset['is_raw']
    ))

# Итоговая таблица
results_df = pd.DataFrame(all_results)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Первоначальные данные] Лучшие параметры RandomForest: {'n_estimators': 100, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 'log2', 'max_depth': 10}
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Предобработанные данные] Лучшие параметры RandomForest: {'n_estimators': 200, 'min_samples_split': 5, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'max_depth': None}
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Сгенерированные признаки] Лучшие параметры RandomForest: {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 'log2', 'max_depth': 8}
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Отобранные признаки] Лучшие параметры RandomForest: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'log2', 'max_depth': None}
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Отобранные признаки без выбросов] Лучшие параметры RandomForest: {'n_estimators': 200, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'log2', 'max_depth': 10}

# %%
# Преобразуем таблицу
pivoted_df = results_df.set_index(['Dataset', 'Model']).unstack()
pivoted_df = pivoted_df.loc[dataset_order]

# Новые цвета моделей
model_colors = {
    'LogisticRegression': "#FFAFCC",  # Розовый
    'RandomForest': "#CDB4DB"         # Фиолетовый
}

# Финальный стиль таблицы
styled_result = (
    pivoted_df.style
        .format("{:.3f}")
        .apply(style_comparison_by_column(pivoted_df), axis=1)
        .set_table_styles(table_styles)
        .set_caption(
            f"<span style='font-size:16pt'>Сравнение моделей: "
            f"<span style='color:{model_colors['LogisticRegression']}; font-weight:bold'>LogisticRegression</span> "
            f"vs <span style='color:{model_colors['RandomForest']}; font-weight:bold'>RandomForest</span></span>"
        )
        .set_properties(**{'min-width': '120px'})
)

styled_result
# Out:
# <style type="text/css">
# #T_b7ffa th {
#   background-color: white;
#   color: black;
#   text-align: center;
#   font-size: 12pt;
#   padding: 5px;
# }
# #T_b7ffa th.level0 {
#   font-weight: bold;
#   border-bottom: 1px solid #aaa;
#   text-align: center;
# }
# #T_b7ffa th.level1 {
#   font-style: italic;
# }
# #T_b7ffa td {
#   padding: 8px;
#   border: 1px solid #eee;
# }
# #T_b7ffa_row0_col0, #T_b7ffa_row0_col2, #T_b7ffa_row0_col6 {
#   background-color: rgb(255,231,239);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row0_col1 {
#   background-color: rgb(225,211,233);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row0_col3 {
#   background-color: rgb(225,210,233);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row0_col4 {
#   background-color: rgb(255,231,239);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row0_col5 {
#   background-color: rgb(220,203,230);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row0_col7 {
#   background-color: rgb(230,218,237);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row1_col0 {
#   background-color: rgb(255,200,220);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row1_col1, #T_b7ffa_row1_col3, #T_b7ffa_row1_col7, #T_b7ffa_row2_col5 {
#   background-color: rgb(205,180,219);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row1_col2 {
#   background-color: rgb(255,208,225);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row1_col4 {
#   background-color: rgb(255,218,231);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row1_col5 {
#   background-color: rgb(240,232,244);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row1_col6 {
#   background-color: rgb(255,198,218);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row2_col0 {
#   background-color: rgb(255,179,207);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row2_col1 {
#   background-color: rgb(215,195,226);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row2_col2 {
#   background-color: rgb(255,187,212);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row2_col3 {
#   background-color: rgb(222,205,231);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row2_col4 {
#   background-color: rgb(255,210,226);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row2_col6, #T_b7ffa_row3_col0, #T_b7ffa_row3_col6, #T_b7ffa_row4_col2 {
#   background-color: rgb(255,175,204);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row2_col7 {
#   background-color: rgb(227,214,235);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row3_col1 {
#   background-color: rgb(223,207,232);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row3_col2 {
#   background-color: rgb(255,186,211);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row3_col3 {
#   background-color: rgb(232,220,238);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row3_col4 {
#   background-color: rgb(255,189,212);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row3_col5 {
#   background-color: rgb(238,229,242);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row3_col7 {
#   background-color: rgb(221,205,231);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row4_col0 {
#   background-color: rgb(255,195,217);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row4_col1, #T_b7ffa_row4_col3, #T_b7ffa_row4_col7 {
#   background-color: rgb(240,232,244);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row4_col4 {
#   background-color: rgb(255,175,204);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   font-weight: bold;
#   color: black;
#   min-width: 120px;
# }
# #T_b7ffa_row4_col5 {
#   background-color: rgb(223,207,232);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# #T_b7ffa_row4_col6 {
#   background-color: rgb(255,202,221);
#   font-size: 12pt;
#   text-align: center;
#   padding: 5px;
#   min-width: 120px;
# }
# </style>
# <table id="T_b7ffa" class="dataframe">
#   <caption><span style='font-size:16pt'>Сравнение моделей: <span style='color:#FFAFCC; font-weight:bold'>LogisticRegression</span> vs <span style='color:#CDB4DB; font-weight:bold'>RandomForest</span></span></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7ffa_level0_col0" class="col_heading level0 col0" colspan="2">F1</th>
#       <th id="T_b7ffa_level0_col2" class="col_heading level0 col2" colspan="2">ROC-AUC</th>
#       <th id="T_b7ffa_level0_col4" class="col_heading level0 col4" colspan="2">Recall</th>
#       <th id="T_b7ffa_level0_col6" class="col_heading level0 col6" colspan="2">Precision</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Model</th>
#       <th id="T_b7ffa_level1_col0" class="col_heading level1 col0" >LogisticRegression</th>
#       <th id="T_b7ffa_level1_col1" class="col_heading level1 col1" >RandomForest</th>
#       <th id="T_b7ffa_level1_col2" class="col_heading level1 col2" >LogisticRegression</th>
#       <th id="T_b7ffa_level1_col3" class="col_heading level1 col3" >RandomForest</th>
#       <th id="T_b7ffa_level1_col4" class="col_heading level1 col4" >LogisticRegression</th>
#       <th id="T_b7ffa_level1_col5" class="col_heading level1 col5" >RandomForest</th>
#       <th id="T_b7ffa_level1_col6" class="col_heading level1 col6" >LogisticRegression</th>
#       <th id="T_b7ffa_level1_col7" class="col_heading level1 col7" >RandomForest</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Dataset</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7ffa_level0_row0" class="row_heading level0 row0" >Первоначальные данные</th>
#       <td id="T_b7ffa_row0_col0" class="data row0 col0" >0.458</td>
#       <td id="T_b7ffa_row0_col1" class="data row0 col1" >0.599</td>
#       <td id="T_b7ffa_row0_col2" class="data row0 col2" >0.747</td>
#       <td id="T_b7ffa_row0_col3" class="data row0 col3" >0.853</td>
#       <td id="T_b7ffa_row0_col4" class="data row0 col4" >0.690</td>
#       <td id="T_b7ffa_row0_col5" class="data row0 col5" >0.684</td>
#       <td id="T_b7ffa_row0_col6" class="data row0 col6" >0.342</td>
#       <td id="T_b7ffa_row0_col7" class="data row0 col7" >0.532</td>
#     </tr>
#     <tr>
#       <th id="T_b7ffa_level0_row1" class="row_heading level0 row1" >Предобработанные данные</th>
#       <td id="T_b7ffa_row1_col0" class="data row1 col0" >0.507</td>
#       <td id="T_b7ffa_ro
